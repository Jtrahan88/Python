# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
y = df['CSIRO Adjusted Sea Level']
x = df['Year']
fig, ax = plt.subplots(figsize=(18,8))
plt.scatter(x,y)

# Create first line of best fit
res = linregress(x, y)
x_pred = pd.Series([i for i in range(1880,2051)]) # years 1880 and 2050
y_pred = res.slope * x_pred + res.intercept
plt.plot(x_pred, y_pred, 'r' )

# Create second line of best fit
new_df = df.loc[df['Year'] >= 2000]
new_x = new_df['Year']
new_y = new_df['CSIRO Adjusted Sea Level']
res2 = linregress(new_x, new_y)
x_pred2 = pd.Series([i for i in range(2000,2051)]) # years 1880 and 2050
y_pred2 = res2.slope * x_pred2 + res2.intercept
plt.plot(x_pred2, y_pred2, 'green' )


# Add labels and title

ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Sea Level Rising')
# Out:
# Text(0.5, 1.0, 'Sea Level Rising')
